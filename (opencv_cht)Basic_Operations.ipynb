# %% [markdown]
# # 更新opencv到最新版

# %%
# !apt update -y
# !apt install libgl1-mesa-glx -y
# !pip install opencv-contrib-python -U
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [635 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,751 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,077 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,404 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [372 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,508 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.5 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [896 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [402 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,176 kB]
# Get:27 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [39.5 kB]
# Fetched 12.6 MB in 3s (3,788 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 40 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libgl1-mesa-glx
# 0 upgraded, 1 newly installed, 0 to remove and 40 not upgraded.
# Need to get 5,532 B of archives.
# After this operation, 79.9 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Fetched 5,532 B in 0s (34.9 kB/s)
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# (Reading database ... 160983 files and directories currently installed.)
# Preparing to unpack .../libgl1-mesa-glx_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Collecting opencv-contrib-python
#   Downloading https://files.pythonhosted.org/packages/17/69/cc755e763f4bb20cb25c7696172e6bb556719faf458c5362f4e54d6cd765/opencv_contrib_python-4.5.1.48-cp37-cp37m-manylinux2014_x86_64.whl (56.3MB)
#      |████████████████████████████████| 56.4MB 71kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python) (1.19.5)
# Installing collected packages: opencv-contrib-python
#   Found existing installation: opencv-contrib-python 4.1.2.30
#     Uninstalling opencv-contrib-python-4.1.2.30:
#       Successfully uninstalled opencv-contrib-python-4.1.2.30
# Successfully installed opencv-contrib-python-4.5.1.48

# %% [markdown]
# # 顯示影像
# * 注意：opencv使用bgr，顯示出來顏色會不正常

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

print(cv2.__version__)
img = cv2.imread('lena.bmp')

# cv2_imshow(img)
print(img.shape)
# Out:
# 4.5.1
# (256, 256, 3)

# %% [markdown]
# # 用rgb顯示影像，使用numpy slicing的方式

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


print(cv2.__version__)
img = cv2.imread('企鵝.jpg')

# plt.imshow(img)
plt.imshow(img[:,:,::-1])
# Out:
# 4.5.1

# %% [markdown]
# # 顯示影像的資訊，如形狀，佔的位元組

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


print(cv2.__version__)
img = cv2.imread('企鵝.jpg')

print(img.shape)
print(img.size)
# Out:
# 4.5.1
# (392, 590, 3)
# 693840

# %% [markdown]
# # 顯示影像真正的矩陣值
# * 注意，opencv使用channel last的方式
# * 如果shape = (a, b, 3)，表示有a個(bx3)的圖片
# * 有些程式是channel first，(3, a, b)因此表示成3個(axb)的圖片

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


print(cv2.__version__)
img = cv2.imread('企鵝.jpg')

print(img.shape)
print(img)
# Out:
# 4.5.1
# (392, 590, 3)
# [[[207 199 192]
#   [208 200 193]
#   [210 202 195]
#   ...
#   [204 199 198]
#   [208 203 202]
#   [210 205 204]]
#
#  [[207 199 192]
#   [207 199 192]
#   [208 200 193]
#   ...
#   [200 195 194]
#   [203 198 197]
#   [204 199 198]]
#
#  [[205 197 190]
#   [205 197 190]
#   [205 197 190]
#   ...
#   [195 190 189]
#   [197 192 191]
#   [197 192 191]]
#
#  ...
#
#  [[206 194 188]
#   [203 193 186]
#   [200 190 183]
#   ...
#   [210 201 197]
#   [209 200 196]
#   [207 198 194]]
#
#  [[205 194 190]
#   [204 193 189]
#   [202 191 187]
#   ...
#   [213 206 203]
#   [215 208 205]
#   [215 208 205]]
#
#  [[212 201 197]
#   [211 200 196]
#   [209 200 196]
#   ...
#   [208 201 198]
#   [207 200 197]
#   [206 199 196]]]

# %% [markdown]
# # 用numpy方式表示圖片，值介於0-1之間

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


print(cv2.__version__)
img = cv2.imread('企鵝.jpg')

img = img / 255
print(img)
plt.imshow(img[:,:,::-1])
# Out:
# 4.5.1
# [[[0.81176471 0.78039216 0.75294118]
#   [0.81568627 0.78431373 0.75686275]
#   [0.82352941 0.79215686 0.76470588]
#   ...
#   [0.8        0.78039216 0.77647059]
#   [0.81568627 0.79607843 0.79215686]
#   [0.82352941 0.80392157 0.8       ]]
#
#  [[0.81176471 0.78039216 0.75294118]
#   [0.81176471 0.78039216 0.75294118]
#   [0.81568627 0.78431373 0.75686275]
#   ...
#   [0.78431373 0.76470588 0.76078431]
#   [0.79607843 0.77647059 0.77254902]
#   [0.8        0.78039216 0.77647059]]
#
#  [[0.80392157 0.77254902 0.74509804]
#   [0.80392157 0.77254902 0.74509804]
#   [0.80392157 0.77254902 0.74509804]
#   ...
#   [0.76470588 0.74509804 0.74117647]
#   [0.77254902 0.75294118 0.74901961]
#   [0.77254902 0.75294118 0.74901961]]
#
#  ...
#
#  [[0.80784314 0.76078431 0.7372549 ]
#   [0.79607843 0.75686275 0.72941176]
#   [0.78431373 0.74509804 0.71764706]
#   ...
#   [0.82352941 0.78823529 0.77254902]
#   [0.81960784 0.78431373 0.76862745]
#   [0.81176471 0.77647059 0.76078431]]
#
#  [[0.80392157 0.76078431 0.74509804]
#   [0.8        0.75686275 0.74117647]
#   [0.79215686 0.74901961 0.73333333]
#   ...
#   [0.83529412 0.80784314 0.79607843]
#   [0.84313725 0.81568627 0.80392157]
#   [0.84313725 0.81568627 0.80392157]]
#
#  [[0.83137255 0.78823529 0.77254902]
#   [0.82745098 0.78431373 0.76862745]
#   [0.81960784 0.78431373 0.76862745]
#   ...
#   [0.81568627 0.78823529 0.77647059]
#   [0.81176471 0.78431373 0.77254902]
#   [0.80784314 0.78039216 0.76862745]]]

# %% [markdown]
# # 隨機產生灰階圖

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


img=np.random.randint(0,256,size=[256,256],dtype=np.uint8)

print(img.shape)
# display(img)
plt.imshow(img)
# Out:
# (256, 256)

# %% [markdown]
# # 隨機產生彩色圖，並且將三個通道取出來

# %%
import cv2
import numpy as np
img=np.random.randint(0,256,size=[256,256,3],dtype=np.uint8)
from google.colab.patches import cv2_imshow


print(img.shape)
display(img[:,:,0])
display(img[:,:,1])
display(img[:,:,2])
plt.imshow(img[:,:,::-1])
# Out:
# (256, 256, 3)
# array([[ 45,  76,  13, ..., 186,  38, 207],
#        [ 95, 202,  77, ...,   1, 191,  83],
#        [ 23,  79, 241, ..., 174, 245,  92],
#        ...,
#        [142, 100, 244, ..., 114,  79, 105],
#        [197, 136,  10, ..., 129,  54, 145],
#        [126,  56,  32, ..., 181, 121,  39]], dtype=uint8)
# array([[209,  11, 156, ...,  89,  22, 116],
#        [183,  89,  10, ..., 117,  66, 117],
#        [ 58, 123, 252, ..., 148,  32,  68],
#        ...,
#        [ 80, 205, 209, ..., 220,  23, 200],
#        [181,  62, 104, ..., 166, 203, 248],
#        [232,  23,  14, ...,  92, 171,   0]], dtype=uint8)
# array([[178, 162,  45, ...,  33,   6,   8],
#        [196,  84, 205, ...,   0, 108, 192],
#        [117,  61,  95, ...,  86, 100, 204],
#        ...,
#        [227, 181, 210, ..., 230, 144, 163],
#        [ 20,  74, 216, ...,   7,  88,   5],
#        [128, 169,  93, ..., 223, 106,  94]], dtype=uint8)

# %% [markdown]
# # 有興趣區域(ROI)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('企鵝.jpg')

part = img[200:400, 250:450]
cv2_imshow(part)
print(part.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=200x192 at 0x7FEF6BA955D0>
# (192, 200, 3)

# %% [markdown]
# # 臉部當作ROI

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

a=cv2.imread("lenacolor.png",cv2.IMREAD_UNCHANGED)

face=np.random.randint(0,256,(180,100,3))
a[220:400,250:350]=face
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FEF6BA95D10>

# %% [markdown]
# # 複製ROI

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


lena=cv2.imread("lena512.bmp",cv2.IMREAD_UNCHANGED)
dollar=cv2.imread("dollar.bmp",cv2.IMREAD_UNCHANGED)
cv2_imshow(dollar)

face=lena[220:400,250:350]
dollar[160:340,200:300]=face

cv2_imshow(lena)
cv2_imshow(dollar)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6B8FC150>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6B8FC110>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6B8FC310>

# %% [markdown]
# # 將不同的通道取出

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


lena=cv2.imread("lenacolor.png",cv2.IMREAD_UNCHANGED)
cv2_imshow(lena[:,:,0])
cv2_imshow(lena[:,:,1])
cv2_imshow(lena[:,:,2])
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6BA95D10>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6B9F69D0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FEF6BA95B90>

# %%
plt.imshow(lena[:,:,1])

# %%
plt.imshow(lena[:,:,2])

# %%
b, g, r = cv2.split(lena)
plt.imshow(b)

# %% [markdown]
# # 重新組合不同channels

# %%
newimage = cv2.merge((r,g,b))
cv2_imshow(newimage)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FEF6AFCB310>

# %% [markdown]
# # 將紅色值全部變成0，只留gb

# %%
r.fill(50)
newimage = cv2.merge((r,g,b))
plt.imshow(newimage)

# %% [markdown]
# # 製作邊界

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


BLUE = [255,0,0]

img1 = cv2.imread('opencv_logo.png')
img1 = img1[:,:,::-1]

replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

fig, ax = plt.subplots(figsize = (15, 5))

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fef6adf94d0>,
#  <matplotlib.image.AxesImage at 0x7fef6ad4de10>,
#  Text(0.5, 1.0, 'CONSTANT'))
